# %%
import sys
sys.path.append("..")

# %%
from models import cut_model
from options.train_options import TrainOptions
from models import create_model

# %%
import torch

# %%
# !python new_train.py  --name grumpycat_CUT --CUT_mode CUT
# Out:
# e:\anaconda\lib\site-packages\torchvision\io\image.py:11: UserWarning: Failed to load image Python extension: Could not find module 'E:\anaconda\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")
# ----------------- Options ---------------
#                  CUT_mode: CUT
#                batch_size: 1
#                     beta1: 0.5
#                     beta2: 0.999
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: placeholder
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: None
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
# ...
